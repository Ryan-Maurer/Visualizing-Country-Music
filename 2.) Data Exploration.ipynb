# %%
import pandas as pd
import time
import seaborn as sns
import matplotlib.pyplot as plt

# %%
country_comb = pd.read_csv('../Visualizing-Country-Music/Visualizing-Country-Music.csv')

# %%
g = sns.FacetGrid(country_comb, col="playlist")
g.map(plt.hist, "acousticness")

# %%
g = sns.FacetGrid(country_comb, col="playlist")
g.map(plt.hist, "danceability")

# %%
g = sns.FacetGrid(country_comb, col="playlist")
g.map(plt.hist, "energy")

# %%
g = sns.FacetGrid(country_comb, col="playlist")
g.map(plt.hist, "loudness")

# %%
g = sns.FacetGrid(country_comb, col="playlist")
g.map(plt.hist, "tempo")

# %%
g = sns.FacetGrid(country_comb, col="playlist")
g.map(plt.hist, "valence")

# %%
g = sns.FacetGrid(country_comb, col="playlist")
g.map(plt.hist, "length")

# %%
#after some exploratory analysis, can remove the speechiness,instrumentalness, and liveness variables

# %%
country_comb = country_comb.drop(columns = ['speechiness',
                                            'instrumentalness',
                                            'liveness',
                                            'release_date',
                                            'popularity',
                                            'time_signature'])

# %%
country_tableau = country_comb

# %%
country_tableau.to_csv('../Visualizing-Country-Music/Country-Music-Tableau.csv')
